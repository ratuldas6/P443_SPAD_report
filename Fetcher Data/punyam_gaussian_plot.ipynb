# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
from scipy.optimize import curve_fit
from scipy.special import factorial
plt.rcParams['figure.figsize'] = [9, 6]
def func(X,C,X_mean,sigma):
    return C*np.exp(-(X-X_mean)**2/(2*sigma**2))

def poisson(k, lamb, scale):
    return scale*(lamb**(k)/factorial(k))*np.exp(-lamb)

# %%
filename = 'fetch_dat_1.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)
counts = counts[counts > 9]
n, bins, patches = plt.hist(counts, 20, alpha=0.75)

bin_heights, bin_borders, _ = plt.hist(counts, 20 , alpha=0.75)
bin_centers = bin_borders[:-1] + np.diff(bin_borders) / 2
popt1, _ = curve_fit(func, bin_centers, bin_heights,[252.40973143, 443.56625041,  16.86611969])
par, test = curve_fit(poisson,bin_centers,bin_heights,[400,500])

x_interval_for_fit = np.linspace(bin_borders[0], bin_borders[-1], 10000)
plt.plot(x_interval_for_fit, func(x_interval_for_fit, *popt1), label='Gaussian fit')
#plt.plot(x_interval_for_fit, poisson(x_interval_for_fit, *par), label='Poisson fit')
plt.legend()
plt.xlabel('No. of incident counts')
plt.ylabel('Frequency of Counts')
plt.title('Histrogram of frequency of counts')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()
print(popt1)
print(par)
print(bin_centers,bin_heights)
print(np.mean(counts))
# Out:
# C:\Users\punya\AppData\Local\Temp/ipykernel_404/4041983424.py:12: RuntimeWarning: overflow encountered in power
#   return scale*(lamb**(k)/factorial(k))*np.exp(-lamb)
# C:\Users\punya\AppData\Local\Temp/ipykernel_404/4041983424.py:12: RuntimeWarning: invalid value encountered in true_divide
#   return scale*(lamb**(k)/factorial(k))*np.exp(-lamb)
# C:\Users\punya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# [505.25616646 443.63789287  16.83846801]
# [400. 500.]
# [403.05 407.15 411.25 415.35 419.45 423.55 427.65 431.75 435.85 439.95
#  444.05 448.15 452.25 456.35 460.45 464.55 468.65 472.75 476.85 480.95] [ 12.  15.  44. 103. 169. 328. 383. 435. 393. 375. 531. 481. 455. 433.
#  352. 260. 143.  58.  21.   9.]
# 443.1578

# %%
filename = 'fetch_dat_2.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)
counts = counts[counts > 9]
n, bins, patches = plt.hist(counts, 20, alpha=0.75)

bin_heights, bin_borders, _ = plt.hist(counts, 20 , alpha=0.75)
bin_centers = bin_borders[:-1] + np.diff(bin_borders) / 2
popt1, _ = curve_fit(func, bin_centers, bin_heights,[252.40973143, 443.56625041,  16.86611969])

x_interval_for_fit = np.linspace(bin_borders[0], bin_borders[-1], 10000)
plt.plot(x_interval_for_fit, func(x_interval_for_fit, *popt1), label='fit')
plt.legend()
plt.xlabel('No. of incident counts')
plt.ylabel('Frequency of Counts')
plt.title('Histrogram of frequency of counts')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()
print(popt1)
# Out:
# [543.24922435 443.01278976  17.07237441]

# %%
filename = 'fetch_dat_3_200ms.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)
counts = counts[counts > 9]
n, bins, patches = plt.hist(counts, 20, alpha=0.75)

bin_heights, bin_borders, _ = plt.hist(counts, 20 , alpha=0.75)
bin_centers = bin_borders[:-1] + np.diff(bin_borders) / 2
popt1, _ = curve_fit(func, bin_centers, bin_heights,[400,4400,10])
par, test = curve_fit(poisson,bin_centers,bin_heights)

x_interval_for_fit = np.linspace(bin_borders[0], bin_borders[-1], 10000)
plt.plot(x_interval_for_fit, func(x_interval_for_fit, *popt1), label='fit')
#plt.plot(x_interval_for_fit, poisson(x_interval_for_fit, *par), label='Poisson fit')
plt.legend()
plt.xlabel('No. of incident counts')
plt.ylabel('Frequency of Counts')
plt.title('Histrogram of frequency of counts')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()
print(popt1)
print(_)
# Out:
# C:\Users\punya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# [ 394.06255113 4478.18982658   34.08045454]
# [[ 2.15285377e+01 -1.28363844e-05 -1.24130292e+00]
#  [-1.28363844e-05  2.14699032e-01  2.63258606e-06]
#  [-1.24130292e+00  2.63258606e-06  2.14708883e-01]]

# %%
filename = 'fetch_dat_4_1500ms_invalid.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)
counts = counts[counts > 9]
n, bins, patches = plt.hist(counts, 20, alpha=0.75)

bin_heights, bin_borders, _ = plt.hist(counts, 20 , alpha=0.75)
bin_centers = bin_borders[:-1] + np.diff(bin_borders) / 2
popt1, _ = curve_fit(func, bin_centers, bin_heights,[252.40973143, 443.56625041,  16.86611969])

x_interval_for_fit = np.linspace(bin_borders[0], bin_borders[-1], 10000)
plt.plot(x_interval_for_fit, func(x_interval_for_fit, *popt1), label='fit')
plt.legend()
plt.xlabel('No. of incident counts')
plt.ylabel('Frequency of Counts')
plt.title('Histrogram of frequency of counts')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()
print(popt1)
# Out:
# C:\Users\punya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# [-3.04776039e-166  4.43548857e+002  1.68657885e+001]

# %%
filename = 'fetch_dat_5_600ms.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)
counts = counts[counts > 9]
n, bins, patches = plt.hist(counts, 20, alpha=0.75)

bin_heights, bin_borders, _ = plt.hist(counts, 20 , alpha=0.75)
bin_centers = bin_borders[:-1] + np.diff(bin_borders) / 2
popt1, _ = curve_fit(func, bin_centers, bin_heights,[60, 13800,  16.86611969])

x_interval_for_fit = np.linspace(bin_borders[0], bin_borders[-1], 10000)
plt.plot(x_interval_for_fit, func(x_interval_for_fit, *popt1), label='fit')
plt.legend()
plt.xlabel('No. of incident counts')
plt.ylabel('Frequency of Counts')
plt.title('Histrogram of frequency of counts')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()
print(popt1)
# Out:
# [   57.76251792 13823.38027986    58.76608838]

# %%
filename = 'fetch_dat_6_10ms.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)
counts = counts[counts > 9]
n, bins, patches = plt.hist(counts, 20, alpha=0.75)

bin_heights, bin_borders, _ = plt.hist(counts, 20 , alpha=0.75)
bin_centers = bin_borders[:-1] + np.diff(bin_borders) / 2
popt1, _ = curve_fit(func, bin_centers, bin_heights,[252.40973143, 443.56625041,  16.86611969])

x_interval_for_fit = np.linspace(bin_borders[0], bin_borders[-1], 10000)
plt.plot(x_interval_for_fit, func(x_interval_for_fit, *popt1), label='fit')
plt.legend()
plt.xlabel('No. of incident counts')
plt.ylabel('Frequency of Counts')
plt.title('Histrogram of frequency of counts')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()
print(popt1)
# Out:
# C:\Users\punya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# [252.40973143 443.56625041  16.86611969]

# %%
filename = 'fetch_dat_7_20ms_741.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)
counts = counts[counts > 9]
n, bins, patches = plt.hist(counts, 20, alpha=0.75)

bin_heights, bin_borders, _ = plt.hist(counts, 20 , alpha=0.75)
bin_centers = bin_borders[:-1] + np.diff(bin_borders) / 2
popt1, _ = curve_fit(func, bin_centers, bin_heights,[252.40973143, 443.56625041,  16.86611969])

x_interval_for_fit = np.linspace(bin_borders[0], bin_borders[-1], 10000)
plt.plot(x_interval_for_fit, func(x_interval_for_fit, *popt1), label='fit')
plt.legend()
plt.xlabel('No. of incident counts')
plt.ylabel('Frequency of Counts')
plt.title('Histrogram of frequency of counts')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()
print(popt1)
# Out:
# [ 27.23584024 454.38596318  17.83731411]

# %%
filename = 'fetch_dat_7_20ms_LED.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)
counts = counts[counts > 9]
n, bins, patches = plt.hist(counts, 20, alpha=0.75)

bin_heights, bin_borders, _ = plt.hist(counts, 20 , alpha=0.75)
bin_centers = bin_borders[:-1] + np.diff(bin_borders) / 2
popt1, _ = curve_fit(func, bin_centers, bin_heights,[252.40973143, 443.56625041,  16.86611969])

x_interval_for_fit = np.linspace(bin_borders[0], bin_borders[-1], 10000)
plt.plot(x_interval_for_fit, func(x_interval_for_fit, *popt1), label='fit')
plt.legend()
plt.xlabel('No. of incident counts')
plt.ylabel('Frequency of Counts')
plt.title('Histrogram of frequency of counts')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()
print(popt1)
# Out:
# [ 30.75343875 479.59846271 -19.11200495]

# %%
filename = 'fetch_dat_1.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)
counts = counts[counts > 9]
n, bins, patches = plt.hist(counts, 20, alpha=0.75)

bin_heights, bin_borders, _ = plt.hist(counts, 20 , alpha=0.75)
bin_centers = bin_borders[:-1] + np.diff(bin_borders) / 2
popt1, _ = curve_fit(func, bin_centers, bin_heights,[252.40973143, 443.56625041,  16.86611969])

x_interval_for_fit = np.linspace(bin_borders[0], bin_borders[-1], 10000)
plt.plot(x_interval_for_fit, func(x_interval_for_fit, *popt1), label='fit')
plt.legend()
plt.xlabel('No. of incident counts')
plt.ylabel('Frequency of Counts')
plt.title('Histrogram of frequency of counts')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()
print(popt1)
# Out:
# [505.25616646 443.63789287  16.83846801]
