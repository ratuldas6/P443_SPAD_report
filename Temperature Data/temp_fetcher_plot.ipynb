# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

# %%
filename = 'Room_25.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)

n, bins, patches = plt.hist(counts, 12, alpha=0.75)

plt.xlabel('Counts')
plt.ylabel('Frequency of counts')
plt.title('Histogram of 200ms data at room temp (25 C)')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
filename = '32.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)

n, bins, patches = plt.hist(counts, 15, alpha=0.75)

plt.xlabel('Counts')
plt.ylabel('Frequency of counts')
plt.title('Histogram of 200ms data at 32 C')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
filename = '39.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)

n, bins, patches = plt.hist(counts, 15, alpha=0.75)

plt.xlabel('Counts')
plt.ylabel('Frequency of counts')
plt.title('Histogram of 200ms data at 39 C')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
filename = '46.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)

n, bins, patches = plt.hist(counts, 15, alpha=0.75)

plt.xlabel('Counts')
plt.ylabel('Frequency of counts')
plt.title('Histogram of 200ms data at 46 C')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
filename = '53.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)

n, bins, patches = plt.hist(counts, 15, alpha=0.75)

plt.xlabel('Counts')
plt.ylabel('Frequency of counts')
plt.title('Histogram of 200ms data at 53 C')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
filename = '60.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)

n, bins, patches = plt.hist(counts, 15, alpha=0.75)

plt.xlabel('Counts')
plt.ylabel('Frequency of counts')
plt.title('Histogram of 200ms data at 60 C')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
filename = '67.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)

n, bins, patches = plt.hist(counts, 15, alpha=0.75)

plt.xlabel('Counts')
plt.ylabel('Frequency of counts')
plt.title('Histogram of 200ms data at 67 C')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
filename = '74.txt'
counts = np.loadtxt(filename, delimiter=',', skiprows=1, dtype=int)

n, bins, patches = plt.hist(counts, 15, alpha=0.75)

plt.xlabel('Counts')
plt.ylabel('Frequency of counts')
plt.title('Histogram of 200ms data at 74 C')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.xlim(40, 160)
#plt.ylim(0, 0.03)
plt.grid(True)
plt.show()

# %%
temps = [25, 32, 39, 46, 53, 60, 67]
peaks = [4330, 4800, 5070, 5240, 5520, 5810, 6050]

x_1 = 20
x_2 = 80

coef = np.polyfit(temps, peaks, 1)
poly1d_fn = np.poly1d(coef)

print(coef)

plt.scatter(temps, peaks, label='Data points', color='black', zorder=3)
plt.plot([x_1,x_2], [coef[0]*x_1+coef[1],coef[0]*x_2+coef[1]],'--k', linewidth=1, label='Best fit line', color='black', zorder=2)

plt.title('Peak dark count plot with temperature')
plt.xlabel('Temp (in ' + r'$^\circ$' + 'C)')
plt.ylabel('Peak Count')
#leg = plt.legend()
#plt.legend(loc='upper left',shadow=True)

plt.grid(zorder=1)
plt.show()
# Out:
# [  38.92857143 3469.28571429]
# C:\Users\Ratul\AppData\Local\Temp\ipykernel_16536\1104831085.py:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--k" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([x_1,x_2], [coef[0]*x_1+coef[1],coef[0]*x_2+coef[1]],'--k', linewidth=1, label='Best fit line', color='black', zorder=2)
